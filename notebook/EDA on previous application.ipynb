# %% [markdown]
# # Exploratory Data Analysis on previous_application.csv
#
# ## 0. Import pacakges

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load the previous_application.csv dataset

# %%
base = pd.read_csv('../data/application_train.csv')
pre_app = pd.read_csv('../data/previous_application.csv')
pos_cash = pd.read_csv('../data/POS_CASH_balance.csv')

# %%
print(f'Base ==> ({base.shape})')
print(f'Previous-Application ==> ({pre_app.shape})')
print(f'POS-Cash ==> ({pos_cash.shape})')
# Out:
# Base ==> ((307511, 122))
# Previous-Application ==> ((1670214, 37))
# POS-Cash ==> ((10001358, 8))

# %%
pre_app.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %% [markdown]
# ## 2. Dataset structure

# %%
for _ in pre_app.columns:
    print(f'{_:30}: {pre_app[_].iloc[0]}')
# Out:
# SK_ID_PREV                    : 2030495
# SK_ID_CURR                    : 271877
# NAME_CONTRACT_TYPE            : Consumer loans
# AMT_ANNUITY                   : 1730.43
# AMT_APPLICATION               : 17145.0
# AMT_CREDIT                    : 17145.0
# AMT_DOWN_PAYMENT              : 0.0
# AMT_GOODS_PRICE               : 17145.0
# WEEKDAY_APPR_PROCESS_START    : SATURDAY
# HOUR_APPR_PROCESS_START       : 15
# FLAG_LAST_APPL_PER_CONTRACT   : Y
# NFLAG_LAST_APPL_IN_DAY        : 1
# RATE_DOWN_PAYMENT             : 0.0
# RATE_INTEREST_PRIMARY         : 0.18283180324152784
# RATE_INTEREST_PRIVILEGED      : 0.8673361522198731
# NAME_CASH_LOAN_PURPOSE        : XAP
# NAME_CONTRACT_STATUS          : Approved
# DAYS_DECISION                 : -73
# NAME_PAYMENT_TYPE             : Cash through the bank
# CODE_REJECT_REASON            : XAP
# NAME_TYPE_SUITE               : nan
# NAME_CLIENT_TYPE              : Repeater
# NAME_GOODS_CATEGORY           : Mobile
# ...

# %%
prev_id = set(pre_app['SK_ID_PREV'])
curr_id = set(pre_app['SK_ID_CURR'])

print(f'{len(prev_id.intersection(curr_id))} duplicate')
# Out:
# 0 duplicate

# %%
pre_app.loc[pre_app['SK_ID_CURR'] == 100006, ['SK_ID_PREV', 'NAME_PAYMENT_TYPE']].sort_values(
by='SK_ID_PREV')
# Out:
#          SK_ID_PREV      NAME_PAYMENT_TYPE
# 1131133     1020698  Cash through the bank
# 1232752     1243599                    XNA
# 900957      1489396                    XNA
# 1607443     1697039  Cash through the bank
# 98162       2078043  Cash through the bank
# 830967      2190416  Cash through the bank
# 1333657     2299329                    XNA
# 1595430     2545789                    XNA
# 617859      2827850                    XNA

# %%
pos_cash.loc[pos_cash['SK_ID_CURR'] == 100006, ['SK_ID_PREV']].sort_values(
by='SK_ID_PREV')
# Out:
#          SK_ID_PREV
# 2299757     2078043
# 2809129     2078043
# 3527715     2078043
# 6832954     2190416
# 9549306     2190416
# 9112813     2190416
# 8423947     2190416
# 8301616     2190416
# 7902400     2190416
# 7098583     2190416
# 6935403     2190416
# 9600306     2190416
# 6407345     2190416
# 6415578     2299329
# 7813685     2299329
# 3226333     2299329
# 2692043     2299329
# 2084324     2299329
# 1632814     2299329
# 9595258     2299329
# 1547042     2299329
